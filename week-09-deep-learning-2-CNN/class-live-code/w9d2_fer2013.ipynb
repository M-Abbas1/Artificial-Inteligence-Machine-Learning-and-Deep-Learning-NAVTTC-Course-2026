# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
path = r"D:\AI\Artificial-Intelligence-Machine-Learning-and-Deep-Learning-Corvit-Peshawar-2026\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\week-09-deep-learning-2\datasets\FER2013"

# %%
os.listdir(path)
# Out:
# ['test', 'train']

# %%
train_path = os.path.join(path, os.listdir(path)[1])

# %%
train_path
# Out:
# 'D:\\AI\\Artificial-Intelligence-Machine-Learning-and-Deep-Learning-Corvit-Peshawar-2026\\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\\week-09-deep-learning-2\\datasets\\FER2013\\train'

# %%
os.listdir(train_path)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
os.listdir(train_path)[0]
# Out:
# 'angry'

# %%
class1_path = os.path.join(train_path, os.listdir(train_path)[0])

# %%
os.listdir(class1_path)[0]
# Out:
# 'Training_10118481.jpg'

# %%
single_image_path = os.path.join(class1_path, os.listdir(class1_path)[0])

# %%
plt.imread(single_image_path)
# Out:
# array([[ 50,  32,  15, ..., 133, 151,  86],
#        [ 57,  34,  22, ..., 138, 151,  89],
#        [ 61,  30,  24, ..., 142, 149,  89],
#        ...,
#        [103, 100, 100, ..., 149, 104,  85],
#        [107, 111, 113, ..., 151, 120,  86],
#        [104, 104, 112, ..., 143, 136,  83]], dtype=uint8)

# %%
from PIL import Image

# %%
a = Image.open(single_image_path)

# %%
print(a)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=48x48 at 0x21007F38BD0>

# %%
np.array(a)
# Out:
# array([[ 50,  32,  15, ..., 133, 151,  86],
#        [ 57,  34,  22, ..., 138, 151,  89],
#        [ 61,  30,  24, ..., 142, 149,  89],
#        ...,
#        [103, 100, 100, ..., 149, 104,  85],
#        [107, 111, 113, ..., 151, 120,  86],
#        [104, 104, 112, ..., 143, 136,  83]], dtype=uint8)

# %%
root_path = r"..\datasets\FER2013"
train_path = os.path.join(root_path, os.listdir(root_path)[1])
test_path = os.path.join(root_path, os.listdir(root_path)[0])

# %%
os.listdir(train_path)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
images = []
labels = []

for class_name in os.listdir(train_path):
    class_path = os.path.join(train_path, class_name)
    
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        img = Image.open(image_path)
        images.append(img)
        labels.append(class_name)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[48], line 9
#       7 for image_name in os.listdir(class_path):
#       8     image_path = os.path.join(class_path, image_name)
# ----> 9     img = Image.open(image_path)
#      10     images.append(img)
#      11     labels.append(class_name)
#
# File c:\Users\Abbas\anaconda3\envs\imageenv\Lib\site-packages\PIL\Image.py:3469, in open(fp, mode, formats)
#
# OSError: [Errno 24] Too many open files: 'D:\\AI\\Artificial-Intelligence-Machine-Learning-and-Deep-Learning-Corvit-Peshawar-2026\\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\\week-09-deep-learning-2\\datasets\\FER2013\\train\\fear\\Training_93080889.jpg'

# %%
len(images)
# Out:
# 8189

# %%
len(labels)
# Out:
# 8189

# %%
images[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=48x48>

# %%
class_names = os.listdir(train_path)

# %%
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
[name for name in os.listdir(train_path) if os.path.isdir(os.path.join(train_path, class_names[0]))]
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
class_path
# Out:
# '..\\datasets\\FER2013\\train\\fear'

# %%
os.listdir(class_path)
# Out:
# ['Training_10018621.jpg',
#  'Training_10031494.jpg',
#  'Training_10110501.jpg',
#  'Training_10117992.jpg',
#  'Training_10126156.jpg',
#  'Training_10127393.jpg',
#  'Training_10133194.jpg',
#  'Training_1018372.jpg',
#  'Training_10208260.jpg',
#  'Training_10230640.jpg',
#  'Training_10247565.jpg',
#  'Training_10283876.jpg',
#  'Training_10323859.jpg',
#  'Training_10352150.jpg',
#  'Training_10395418.jpg',
#  'Training_1040092.jpg',
#  'Training_1044537.jpg',
#  'Training_10510421.jpg',
#  'Training_10511162.jpg',
#  'Training_10512405.jpg',
#  'Training_10528695.jpg',
#  'Training_10561429.jpg',
#  'Training_10573197.jpg',
#  'Training_10614740.jpg',
#  'Training_10662098.jpg',
#  'Training_10662291.jpg',
#  'Training_10710108.jpg',
#  'Training_1071075.jpg',
#  'Training_10764539.jpg',
#  'Training_1077665.jpg',
#  'Training_10786063.jpg',
#  'Training_10833439.jpg',
#  'Training_10833994.jpg',
#  'Training_10834306.jpg',
#  'Training_10842121.jpg',
# ...
