# %%
student = {
    "name":"muhammad ibad",
    "age" : 40,
    "semester" : 4,
    "sub" : ["python", 'java', 'C++'],
    "marks" : [80, 60, 50],
    "gpa" : 3.6,
}

# %%
student['age']
# Out:
# 40

# %%
print("Name  : ", student['name'])
print("Age  : ", student['age'])
print("Semester  : ", student['semester'])
print("Subjects  : ", student['sub'])
print("Marks  : ", student['marks'])
print("GPA  : ", student['gpa'])
# Out:
# Name  :  muhammad ibad
# Age  :  40
# Semester  :  4
# Subjects  :  ['python', 'java', 'C++']
# Marks  :  [80, 60, 50]
# GPA  :  3.6

# %%
student.get("age")
# Out:
# 40

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++'],
#  'marks': [80, 60, 50],
#  'gpa': 3.6}

# %%
student['gpa'] = 3.0

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++'],
#  'marks': [80, 60, 50],
#  'gpa': 3.0}

# %%
current_gpa = student.get("gpa")

# %%
current_gpa
# Out:
# 3.0

# %%
new_gpa = current_gpa +  current_gpa * 0.1

# %%
new_gpa
# Out:
# 3.3

# %%
student['gpa'] = new_gpa

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++'],
#  'marks': [80, 60, 50],
#  'gpa': 3.3}

# %%
# student['gpa'] = student["gpa"] + student["gpa"] * 0.1

# %%
student['gpa'] += student["gpa"] * 0.1

# %%
student['gpa']
# Out:
# 3.63

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++'],
#  'marks': [80, 60, 50],
#  'gpa': 3.63}

# %%
student['sub'].append("ML")

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50],
#  'gpa': 3.63}

# %%
student['marks'].append(69)

# %%
student
# Out:
# {'name': 'muhammad ibad',
#  'age': 40,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69],
#  'gpa': 3.63}

# %%
student.update({'name':"Muhammad Ibad", 'age':20, 'contact':"3773883837"})

# %%
student
# Out:
# {'name': 'Muhammad Ibad',
#  'age': 20,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69],
#  'gpa': 3.63,
#  'contact': '3773883837'}

# %%
student.pop('contact')
# Out:
# '3773883837'

# %%
student
# Out:
# {'name': 'Muhammad Ibad',
#  'age': 20,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69],
#  'gpa': 3.63}

# %%
student.popitem()
# Out:
# ('gpa', 3.63)

# %%
student
# Out:
# {'name': 'Muhammad Ibad',
#  'age': 20,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69]}

# %%
student['gpa'] = 3.63

# %%
student
# Out:
# {'name': 'Muhammad Ibad',
#  'age': 20,
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69],
#  'gpa': 3.63}

# %%
del student['age']

# %%
student
# Out:
# {'name': 'Muhammad Ibad',
#  'semester': 4,
#  'sub': ['python', 'java', 'C++', 'ML'],
#  'marks': [80, 60, 50, 69],
#  'gpa': 3.63}

# %%
del student['major']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 del student['major']
#
# KeyError: 'major'

# %%
student.pop('major', 0)
# Out:
# 0

# %%
student.keys()
# Out:
# dict_keys(['name', 'semester', 'sub', 'marks', 'gpa'])

# %%
student.values()
# Out:
# dict_values(['Muhammad Ibad', 4, ['python', 'java', 'C++', 'ML'], [80, 60, 50, 69], 3.63])

# %%
student.items()
# Out:
# dict_items([('name', 'Muhammad Ibad'), ('semester', 4), ('sub', ['python', 'java', 'C++', 'ML']), ('marks', [80, 60, 50, 69]), ('gpa', 3.63)])

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
id(student)
# Out:
# 1958433088512

# %%
len(student)
# Out:
# 0

# %%
student

# %%
students = {
    "student1": {
        "name": "Alice",
        "age": 20,
        "grades": {"math": 90, "english": 85}
    },
    "student2": {
        "name": "Bob",
        "age": 22,
        "grades": {"math": 88, "english": 92}
    }
}

# %%
students['student2']['grades']
# Out:
# {'math': 88, 'english': 92}

# %%
students['student1']['grades']['math']
# Out:
# 90

# %%
students['student2']['grades']['english']
# Out:
# 92

# %%
students
# Out:
# {'student1': {'name': 'Alice',
#   'age': 20,
#   'grades': {'math': 90, 'english': 85}},
#  'student2': {'name': 'Bob', 'age': 22, 'grades': {'math': 88, 'english': 92}}}

# %%
students.setdefault("gpa", 0)
# Out:
# 0

# %%
students
# Out:
# {'student1': {'name': 'Alice',
#   'age': 20,
#   'grades': {'math': 90, 'english': 85}},
#  'student2': {'name': 'Bob', 'age': 22, 'grades': {'math': 88, 'english': 92}},
#  'gpa': 0}

# %%
students['gpa']
# Out:
# 0

# %%
##

# %% [markdown]
# ## tuple

# %%
t = tuple()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t2 = (42, 53, 64)

# %%
t2
# Out:
# (42, 53, 64)

# %%
t2[0]
# Out:
# 42

# %%
t2[-1]
# Out:
# 64

# %%
t2[-2]
# Out:
# 53

# %%
t2.append(68)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 t2.append(68)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t2[2] = 58
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 t2[2] = 58
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 t2.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t2
# Out:
# (42, 53, 64)

# %%
a, b, c = t2

# %%
t2
# Out:
# (42, 53, 64)

# %%
print(a)
print(b)
print(c)
# Out:
# 42
# 53
# 64

# %%
t3 = 12, 53, 23

# %%
t3
# Out:
# (12, 53, 23)

# %%
type(t3)
# Out:
# tuple

# %%
students
# Out:
# {'student1': {'name': 'Alice',
#   'age': 20,
#   'grades': {'math': 90, 'english': 85}},
#  'student2': {'name': 'Bob', 'age': 22, 'grades': {'math': 88, 'english': 92}},
#  'gpa': 0}

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Alice', 'age': 20, 'grades': {'math': 90, 'english': 85}}), ('student2', {'name': 'Bob', 'age': 22, 'grades': {'math': 88, 'english': 92}}), ('gpa', 0)])

# %%
d
# Out:
# {1: 'khan', 2: 'khalid'}

# %%
d.items()
# Out:
# dict_items([(1, 'khan'), (2, 'khalid')])

# %%
d.items()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 d.items()[0]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
lkv = list(d.items())

# %%
lkv
# Out:
# [(1, 'khan'), (2, 'khalid')]

# %%
lkv[0]
# Out:
# (1, 'khan')

# %%
lkv[1][0]
# Out:
# 2

# %%
t3
# Out:
# (12, 53, 23)

# %%
t3[:]
# Out:
# (12, 53, 23)

# %%
t3[0:2]
# Out:
# (12, 53)

# %%
##

# %% [markdown]
# ## Set

# %%
name = "muhammad"

# %%
name[2] = "H"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 name[2] = "H"
#
# TypeError: 'str' object does not support item assignment

# %%
id(name)
# Out:
# 1958439769840

# %%
name = name + 'luqman'

# %%
name
# Out:
# 'muhammadluqman'

# %%
id(name)
# Out:
# 1958439752432

# %%
s1 = set()

# %%
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
s1 = {1, 4, 6, 2, 7}

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
names = {'ahmad', 'ali', 'basit', 'salman', 'kamran'}

# %%
names
# Out:
# {'ahmad', 'ali', 'basit', 'kamran', 'salman'}

# %%
type(names)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
s1.add(2)

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
s2 = {85, 75, 32, 75, 23}

# %%
s2
# Out:
# {23, 32, 75, 85}

# %%
print(id(s2))
# Out:
# 1958441863648

# %%
s2.add(90)

# %%
s2
# Out:
# {23, 32, 75, 85, 90}

# %%
print(id(s2))
# Out:
# 1958441863648

# %%
s3 = {"apple", 3.25, 521, True, (3, 5), {'name':'aslam'}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 s3 = {"apple", 3.25, 521, True, (3, 5), {'name':'aslam'}}
#
# TypeError: unhashable type: 'dict'

# %%
s3
# Out:
# {(3, 5), 3.25, 521, True, 'apple'}

# %%
s3
# Out:
# {(3, 5), 3.25, 521, True, 'apple'}

# %%
s4 = {64, 27, 75, 23, 57, 87, 34}

# %%
s4
# Out:
# {23, 27, 34, 57, 64, 75, 87}

# %%
A = {1, 2, 3, 5, 6}
B = {4, 5, 6, 7, 8}

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A.intersection(B)
# Out:
# {5, 6}

# %%
A.difference(B)
# Out:
# {1, 2, 3}

# %%
A
# Out:
# {1, 2, 3, 5, 6}

# %%
B
# Out:
# {4, 5, 6, 7, 8}

# %%
A.symmetric_difference(B)
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
A + B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 A + B
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
(2, 53) + (64, 23)
# Out:
# (2, 53, 64, 23)

# %%
[53, 23, 64] + [75, 23, 654]
# Out:
# [53, 23, 64, 75, 23, 654]

# %%
l = [62, 46, 53, 23, 64, 86, 23, 65, 86, 34, 53, 78]

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# [62, 46, 53, 23, 64, 86, 23, 65, 86, 34, 53, 78]

# %%
set(l)
# Out:
# {23, 34, 46, 53, 62, 64, 65, 78, 86}

# %%
l.duplicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 l.duplicate()
#
# AttributeError: 'list' object has no attribute 'duplicate'

# %%
s3
# Out:
# {(3, 5), 3.25, 521, True, 'apple'}

# %%
s3.pop()
# Out:
# True

# %%
s3.pop()
# Out:
# 3.25

# %%
s3
# Out:
# {(3, 5), 521, 'apple'}

# %%
s3.remove('apple')

# %%
s3
# Out:
# {(3, 5), 521}

# %%
s2
# Out:
# {23, 32, 75, 85, 90}

# %%
s2.discard(32)

# %%
s2
# Out:
# {23, 75, 85, 90}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s4
# Out:
# {23, 27, 34, 57, 64, 75, 87}

# %%
s5 = frozenset({23, 53, 23})

# %%
s5
# Out:
# frozenset({23, 53})

# %%
s5.remove(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 s5.remove(23)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
s5.discard(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 s5.discard(23)
#
# AttributeError: 'frozenset' object has no attribute 'discard'

# %%
s5.add(85)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 s5.add(85)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s2
# Out:
# set()

# %%
s2.add(43)

# %%
s2
# Out:
# {43}

# %%
type(s5)
# Out:
# frozenset

# %%
l = [53, 64, 23, 675, 3]

s = set(l)

# %%
s
# Out:
# {3, 23, 53, 64, 675}

# %%
l = list({53, 23, 64, 234, 64})

# %%
l
# Out:
# [64, 234, 53, 23]

# %%
import math

math.sqrt(4)
# Out:
# 2.0

# %%
s = [
    ("ahmad", 20, "A", 3.8), 
    ("ahmad", 20, "A", 3.8),
    ("ahmad", 20, "A", 3.8), 
    ("ahmad", 20, "A", 3.8),
    ("ahmad", 20, "A", 3.8),
]

s[]
# Out:
# ('ahmad', 20, 'A', 3.8)
