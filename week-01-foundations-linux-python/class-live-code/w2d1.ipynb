# %% [markdown]
# ## List data structure

# %%
students = ["tauqeer", 'shafi', "shakoor"]

# %%
print(students[0])
# Out:
# tauqeer

# %%
print(students[-1])
# Out:
# shakoor

# %%
len(students)
# Out:
# 3

# %%
id(students)
# Out:
# 2411459582272

# %%
empty = []

# %%
empty[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 empty[0]
#
# IndexError: list index out of range

# %%
empty1 = list()

# %%
empty1
# Out:
# []

# %%
age = int(20)

# %%
age
# Out:
# 20

# %%
student = [2131, "khan", 3.8, True]

# %%
student
# Out:
# [2131, 'khan', 3.8, True]

# %%
fruits = ['apple', 'orange', 'mango', 'banana']

# %%
print(id(fruits))
# Out:
# 2411465414656

# %%
fruits.append("grapes")

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes']

# %%
fruit = "peach"

fruits.append(fruit)

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes', 'peach']

# %%
fruit = input("Enter a fruit name : " )

fruits.append(fruit)

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes', 'peach', 'watermelon']

# %%
fruits.append(input("Enter Fruit Name : "))

# %%
fruits2 = ["pineapple", 'stawberry']

# %%
fruits2
# Out:
# ['pineapple', 'stawberry']

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes', 'peach', 'watermelon']

# %%
fruits.append(fruits2)

# %%
fruits
# Out:
# ['apple',
#  'orange',
#  'mango',
#  'banana',
#  'grapes',
#  'peach',
#  'watermelon',
#  ['pineapple', 'stawberry']]

# %%
len(fruits)
# Out:
# 8

# %%
fruits[-1]
# Out:
# ['pineapple', 'stawberry']

# %%
fruits.pop()
# Out:
# ['pineapple', 'stawberry']

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes', 'peach', 'watermelon']

# %%
fruits.remove("watermelon")

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'grapes', 'peach']

# %%
pop_item = fruits.pop()

# %%
pop_item
# Out:
# 'peach'

# %%
rem_itme = fruits.remove("banana")

# %%
print(rem_itme)
# Out:
# None

# %%
fruits.append(["banana", 'orange'])

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', ['banana', 'orange']]

# %%
fruits.remove(['banana', 'orange'])

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes']

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', ['banana', 'orange']]

# %%
fruits.pop()
# Out:
# ['banana', 'orange']

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes']

# %%
fruits.extend(["banana", 'orange'])

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', 'banana', 'orange']

# %%
len(fruits)
# Out:
# 6

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', 'banana', 'orange']

# %%
fruits[3]
# Out:
# 'grapes'

# %%
fruits[-4]
# Out:
# 'mango'

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', 'banana', 'orange']

# %%
fruits[0][0]
# Out:
# 'a'

# %%
fruits[0][0]
# Out:
# 'a'

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'grapes', 'banana', 'orange']

# %%
fruits.append(['orange', 'mango', 'grapes'])

# %%
fruits
# Out:
# ['apple',
#  'orange',
#  'mango',
#  'grapes',
#  'banana',
#  'orange',
#  ['orange', 'mango', 'grapes']]

# %%
fruits[-1][0]
# Out:
# 'orange'

# %%
fruits[-1][::]
# Out:
# ['orange', 'mango', 'grapes']

# %%
fruits[4][::-1]
# Out:
# 'ananab'

# %%
fruits = ['apple', 'orange', 'mango', 'banana']

# %%
id(fruits)
# Out:
# 2411465412672

# %%
fruits.append("peach")

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'peach']

# %%
id(fruits)
# Out:
# 2411465412672

# %%
name = 'khalid'
id(name)
# Out:
# 2411465960560

# %%
name = "Muhammad" + " " + "Khalid"

# %%
id(name)
# Out:
# 2411459622704

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'peach']

# %%
fruits[4] = "watermelon"

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'watermelon']

# %%
id(fruits)  # 2411465412672
# Out:
# 2411465412672

# %%
name
# Out:
# 'Muhammad Khalid'

# %%
name[0] = 'm'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 name[0] = 'm'
#
# TypeError: 'str' object does not support item assignment

# %%
address = "tehkal bala, peshawar"

# %%
address.find("a")
# Out:
# 4

# %%
address.index('a')
# Out:
# 4

# %%
address.find('z')
# Out:
# -1

# %%
address.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 address.index('z')
#
# ValueError: substring not found

# %%
student_marks  = [59, 40, 38, 48, 59]

# %%
student_marks.index(38)
# Out:
# 2

# %%
student_marks.count(59)
# Out:
# 2

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'banana', 'watermelon']

# %%
fruits.count("apple")
# Out:
# 1

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
fruits2
# Out:
# ['pineapple', 'stawberry']

# %%
id(fruits)
# Out:
# 2411465412672

# %%
fruits
# Out:
# []

# %%
del fruits2

# %%
fruits2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 fruits2
#
# NameError: name 'fruits2' is not defined

# %%
fruits
# Out:
# []

# %%
del fruits

# %%
fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 fruits
#
# NameError: name 'fruits' is not defined

# %%
student_marks
# Out:
# [59, 40, 38, 48, 59]

# %%
student_marks.insert(2, 80)

# %%
student_marks
# Out:
# [59, 40, 80, 38, 48, 59]

# %%
student_marks.reverse()

# %%
student_marks
# Out:
# [59, 48, 38, 80, 40, 59]

# %%
address
# Out:
# 'tehkal bala, peshawar'

# %%
address.split()
# Out:
# ['tehkal', 'bala,', 'peshawar']

# %%
address
# Out:
# 'tehkal bala, peshawar'

# %%
student_marks
# Out:
# [59, 48, 38, 80, 40, 59]

# %%
student_marks.sort()

# %%
student_marks
# Out:
# [38, 40, 48, 59, 59, 80]

# %%
student_marks.sorted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 student_marks.sorted()
#
# AttributeError: 'list' object has no attribute 'sorted'

# %%
student_marks
# Out:
# [38, 40, 48, 59, 59, 80]

# %%
id(student_marks)
# Out:
# 2411466077504

# %%
student_marks2 = student_marks

# %%
id(student_marks)
# Out:
# 2411466077504

# %%
student_marks
# Out:
# [38, 40, 48, 59, 59, 80]

# %%
student_marks2[0] = 70

# %%
student_marks2
# Out:
# [70, 40, 48, 59, 59, 80]

# %%
student_marks
# Out:
# [70, 40, 48, 59, 59, 80]

# %%
student_marks3 = student_marks.copy()

# %%
id(student_marks)
# Out:
# 2411466077504

# %%
id(student_marks3)
# Out:
# 2411466517760

# %%
student_marks4 = student_marks[:]

# %%
id(student_marks4)
# Out:
# 2411466641280

# %%
student_marks[:]
# Out:
# [70, 40, 48, 59, 59, 80]

# %%
sm = student_marks[:]

# %%
id(student_marks)
# Out:
# 2411466077504

# %%
id(sm)
# Out:
# 2411465303296

# %%
sm[0] = 40

# %%
print(sm)
print(student_marks)
# Out:
# [40, 40, 48, 59, 59, 80]
# [70, 40, 48, 59, 59, 80]

# %%
sum(student_marks)
# Out:
# 356

# %%
sum(student_marks)/len(student_marks)
# Out:
# 59.333333333333336

# %%
round(sum(student_marks)/len(student_marks), 2)
# Out:
# 59.33

# %%
round(3.14155333, 3)
# Out:
# 3.142

# %% [markdown]
# ## Dictionary

# %%
student = {"name":"Ali", "age":30}

# %%
student
# Out:
# {'name': 'Ali', 'age': 30}

# %%
student['name']
# Out:
# 'Ali'

# %%
student['age']
# Out:
# 30

# %%
student['Ali']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 student['Ali']
#
# KeyError: 'Ali'

# %%
student['name']
# Out:
# 'Ali'

# %%
empty = dict()

# %%
empty
# Out:
# {}

# %%
len(student)
# Out:
# 2

# %%
student
# Out:
# {'name': 'Ali', 'age': 30}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.values()
# Out:
# dict_values(['Ali', 30])

# %%
student.items()
# Out:
# dict_items([('name', 'Ali'), ('age', 30)])

# %%
student
# Out:
# {'name': 'Ali', 'age': 30}

# %%
student['gps'] = 3.8

# %%
student
# Out:
# {'name': 'Ali', 'age': 30, 'gps': 3.8}

# %%
student['gps']
# Out:
# 3.8

# %%
student.get('gps')
# Out:
# 3.8

# %%
student['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 student['address']
#
# KeyError: 'address'

# %%
student.get("address")

# %%
print("hil")
# Out:
# hil

# %%
name = "khan"

# %%
name.
