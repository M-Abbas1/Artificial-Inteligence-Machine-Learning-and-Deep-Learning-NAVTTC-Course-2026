# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv(r"D:\AI\Artificial-Intelligence-Machine-Learning-and-Deep-Learning-Corvit-Peshawar-2026\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\week-05-visualization-first-models-and-ML\datasets\students.csv")

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  PESHAWAR    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0      1.91         68.5            0
# 1       NaN         54.4            0
# 2       NaN         68.7            0
# 3      2.84         56.8            0
# 4       NaN         68.8            0

# %%
df.shape
# Out:
# (184, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    object
#  1   gender       184 non-null    object
#  2   city         184 non-null    object
#  3   program      184 non-null    object
#  4   semester     184 non-null    int64
#  5   study_hours  179 non-null    float64
#  6   attendance   168 non-null    float64
#  7   prev_gpa     174 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 14.5+ KB

# %%
for column in ["study_hours", "attendance", 'prev_gpa']:
    df[column] = df[column].fillna(df[column].mean())

# %%
df.isnull().sum()
# Out:
# student_id     0
# gender         0
# city           0
# program        0
# semester       0
# study_hours    0
# attendance     0
# prev_gpa       0
# final_marks    0
# scholarship    0
# dtype: int64

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'] = df['gender'].str.title()

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.city.unique()
# Out:
# array(['Quetta', 'Karachi', 'Lahore', 'PESHAWAR', 'Peshawar', 'KARACHI',
#        'Multan', 'Islamabad'], dtype=object)

# %%
df['city'] = df['city'].str.title()

# %%
df.city.unique()
# Out:
# array(['Quetta', 'Karachi', 'Lahore', 'Peshawar', 'Multan', 'Islamabad'],
#       dtype=object)

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
sns.regplot(data=df, x="attendance", y='final_marks')
# Out:
# <Axes: xlabel='attendance', ylabel='final_marks'>

# %%
df[['attendance', 'study_hours']].corr()
# Out:
#              attendance  study_hours
# attendance     1.000000    -0.031473
# study_hours   -0.031473     1.000000

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'city', 'program', 'semester', 'study_hours',
#        'attendance', 'prev_gpa', 'final_marks', 'scholarship'],
#       dtype='object')

# %%
sns.regplot(data=df, x='study_hours', y="final_marks")
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
df[['study_hours', 'final_marks']].corr()
# Out:
#              study_hours  final_marks
# study_hours     1.000000     0.655732
# final_marks     0.655732     1.000000

# %%
sns.histplot(data=df, x='study_hours')
plt.title("Histogram of Study Hours")
plt.show()

# %%
sns.histplot(data=df, x='study_hours', kde=True)
plt.title("Histogram of Study Hours")
plt.show()

# %%
tick = np.linspace(df['study_hours'].min(), df['study_hours'].max(), 11)

sns.histplot(data=df, x='study_hours', kde=True, bins=10)
plt.xticks(tick)
plt.title("Histogram of Study Hours")
plt.show()

# %%
df['study_hours'][df['study_hours'] < 3.45].shape
# Out:
# (39,)

# %%
sns.boxplot(data=df, x='final_marks', color='r')
plt.title("Box plot for final marks")
# Out:
# Text(0.5, 1.0, 'Box plot for final marks')

# %%
np.percentile(df['study_hours'], 25)
# Out:
# 3.85

# %%
sns.boxplot(data=df, x='final_marks', color='r')
plt.axvline(np.percentile(df['final_marks'], 25))
plt.title("Box plot for final marks")
# Out:
# Text(0.5, 1.0, 'Box plot for final marks')

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
sns.countplot(data=df, x='gender', width=0.1, )
plt.title("Number of Male and Females")
plt.show()

# %%
sns.countplot(x='program', data=df)
plt.grid()
plt.show()

# %%
sns.barplot(data=df, x="city", y="final_marks")
# Out:
# <Axes: xlabel='city', ylabel='final_marks'>

# %%
df.groupby('city')['final_marks'].mean()
# Out:
# city
# Islamabad    67.185000
# Karachi      62.658333
# Lahore       63.565517
# Multan       61.889474
# Peshawar     66.681034
# Quetta       67.990909
# Name: final_marks, dtype: float64

# %%
sns.violinplot(data=df, x='city')
plt.show()

# %%
sns.boxplot(data=df, x='final_marks', y='program')
# Out:
# <Axes: xlabel='final_marks', ylabel='program'>

# %%
sns.scatterplot(data=df, x='study_hours', y='final_marks')
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
sns.regplot(data=df, x='study_hours', y='final_marks', label='marks', scatter_kws={"alpha":0.8}, line_kws={"color":'red', 'label':'Reg line'})
plt.legend()

# %%
sns.pairplot(data=df[['study_hours', 'prev_gpa', 'attendance', 'semester', 'final_marks']])

# %%
df[['semester', 'final_marks']].corr()
# Out:
#              semester  final_marks
# semester     1.000000    -0.040782
# final_marks -0.040782     1.000000

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
df.scholarship.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.boxplot(data=df, x='scholarship', y='final_marks')
# Out:
# <Axes: xlabel='scholarship', ylabel='final_marks'>

# %%
x = df[['study_hours', 'attendance', 'prev_gpa']]

# %%
x.head()
# Out:
#    study_hours  attendance  prev_gpa
# 0          8.1        87.5  1.910000
# 1          5.2        77.4  2.839655
# 2          4.0        96.9  2.839655
# 3          2.5       100.0  2.840000
# 4          7.7        87.8  2.839655

# %%
y = df['final_marks']
y.head()
# Out:
# 0    68.5
# 1    54.4
# 2    68.7
# 3    56.8
# 4    68.8
# Name: final_marks, dtype: float64

# %%
arr = np.array([
    [40, 60, 30],
    [60, 80, 20],
    [50, 90, 100]
])

# %%
sns.heatmap(arr, vmin=0, vmax=100, cmap='coolwarm')
# Out:
# <Axes: >

# %%
cor = df[["attendance", 'study_hours', 'prev_gpa', 'final_marks']].corr()

# %%
cor
# Out:
#              attendance  study_hours  prev_gpa  final_marks
# attendance     1.000000    -0.031473  0.007365     0.308842
# study_hours   -0.031473     1.000000  0.062176     0.655732
# prev_gpa       0.007365     0.062176  1.000000     0.278158
# final_marks    0.308842     0.655732  0.278158     1.000000

# %%
sns.heatmap(cor, vmin=-1, vmax=1, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].scatter(df['study_hours'], df['final_marks'])
ax[0].set_title("Study Hours vs Final Marks")
ax[0].set_xlabel("Study Hours")
ax[0].set_ylabel("Final Marks")

ax[1].scatter(df['attendance'], df['final_marks'])
ax[1].set_title("Attendance vs Final Marks")
ax[1].set_xlabel("Attendance")
ax[1].set_ylabel("Final Marks")
# Out:
# Text(0, 0.5, 'Final Marks')
