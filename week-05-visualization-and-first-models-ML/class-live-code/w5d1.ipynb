# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
day = ['mon', 'tue', 'wen', 'thu', 'fri', 'sat', 'sun']
temp = [30.6, 40.0, 29.8, 25.5, 30.5, 33.6, 42.5]

plt.plot(day, temp)

# %%
plt.plot(day, temp)
plt.xlabel("Day")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.plot(day, temp)
plt.title("Weekly Temprature")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.show()

# %%
x = np.arange(0, 10)

plt.plot(x)

# %%
plt.plot(day, temp, marker="*")
plt.title("Weekly Temprature")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.show()

# %%
plt.plot(day, temp, marker="*", color='#ba1894')
plt.title("Weekly Temprature")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.show()

# %%
df = pd.read_csv(r"D:\AI\Artificial-Intelligence-Machine-Learning-and-Deep-Learning-Corvit-Peshawar-2026\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\week-05-visualization-first-models-and-ML\datasets\students.csv")
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  PESHAWAR    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0      1.91         68.5            0
# 1       NaN         54.4            0
# 2       NaN         68.7            0
# 3      2.84         56.8            0
# 4       NaN         68.8            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    object
#  1   gender       184 non-null    object
#  2   city         184 non-null    object
#  3   program      184 non-null    object
#  4   semester     184 non-null    int64
#  5   study_hours  179 non-null    float64
#  6   attendance   168 non-null    float64
#  7   prev_gpa     174 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 14.5+ KB

# %%
df['study_hours'].fillna(df['study_hours'].mean(), inplace=True)
# Out:
# C:\Users\Abbas\AppData\Local\Temp\ipykernel_8816\392308505.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['study_hours'].fillna(df['study_hours'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id      0
# gender          0
# city            0
# program         0
# semester        0
# study_hours     0
# attendance     16
# prev_gpa       10
# final_marks     0
# scholarship     0
# dtype: int64

# %%
df['attendance'].fillna(df['attendance'].median())
# Out:
# 0       87.5
# 1       77.4
# 2       96.9
# 3      100.0
# 4       87.8
#        ...
# 179     68.6
# 180     70.1
# 181     82.0
# 182     97.8
# 183     75.5
# Name: attendance, Length: 184, dtype: float64

# %%
df.isnull().sum()
# Out:
# student_id      0
# gender          0
# city            0
# program         0
# semester        0
# study_hours     0
# attendance     16
# prev_gpa       10
# final_marks     0
# scholarship     0
# dtype: int64

# %%
df['attendance'].fillna(df['attendance'].median(), inplace=True)
# Out:
# C:\Users\Abbas\AppData\Local\Temp\ipykernel_8816\2661820941.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['attendance'].fillna(df['attendance'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id      0
# gender          0
# city            0
# program         0
# semester        0
# study_hours     0
# attendance      0
# prev_gpa       10
# final_marks     0
# scholarship     0
# dtype: int64

# %%
df["prev_gpa"].fillna(df['prev_gpa'].mean(), inplace=True)
# Out:
# C:\Users\Abbas\AppData\Local\Temp\ipykernel_8816\4148441743.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["prev_gpa"].fillna(df['prev_gpa'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    object
#  1   gender       184 non-null    object
#  2   city         184 non-null    object
#  3   program      184 non-null    object
#  4   semester     184 non-null    int64
#  5   study_hours  184 non-null    float64
#  6   attendance   184 non-null    float64
#  7   prev_gpa     184 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 14.5+ KB

# %%
pd.unique(df['gender'])
# Out:
# array(['Female', 'Male', 'male', 'female'], dtype=object)

# %%
df['gender'] = df['gender'].str.title()

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'city', 'program', 'semester', 'study_hours',
#        'attendance', 'prev_gpa', 'final_marks', 'scholarship'],
#       dtype='object')

# %%
df.city.unique()
# Out:
# array(['Quetta', 'Karachi', 'Lahore', 'PESHAWAR', 'Peshawar', 'KARACHI',
#        'Multan', 'Islamabad'], dtype=object)

# %%
df['city'] = df['city'].str.title()

# %%
df.city.unique()
# Out:
# array(['Quetta', 'Karachi', 'Lahore', 'Peshawar', 'Multan', 'Islamabad'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'city', 'program', 'semester', 'study_hours',
#        'attendance', 'prev_gpa', 'final_marks', 'scholarship'],
#       dtype='object')

# %%
df.program.unique()
# Out:
# array(['BBA', 'BSSE', 'BSCS', 'BSEE'], dtype=object)

# %%
df.semester.unique()
# Out:
# array([1, 7, 3, 4, 2, 5, 8, 6], dtype=int64)

# %%
df.scholarship.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
plt.plot(df['study_hours'], df['final_marks'])

# %%
df[["study_hours", 'final_marks']]
# Out:
#      study_hours  final_marks
# 0            8.1         68.5
# 1            5.2         54.4
# 2            4.0         68.7
# 3            2.5         56.8
# 4            7.7         68.8
# ..           ...          ...
# 179          5.5         56.0
# 180          3.5         63.5
# 181          1.4         65.3
# 182          7.9         71.5
# 183          6.3         57.8
#
# [184 rows x 2 columns]

# %%
plt.scatter(df['study_hours'], df['final_marks'])
plt.title("Study Housr vs Final Marks")
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")
plt.show()

# %%
pd.corr(df['study_hours'], df['final_marks'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pd.corr(df['study_hours'], df['final_marks'])
#
# AttributeError: module 'pandas' has no attribute 'corr'

# %%
df['study_hours'].corr(df['final_marks'])
# Out:
# 0.655731631994193

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
df['semester'].corr(df['final_marks'])
# Out:
# -0.04078183669782071

# %%
plt.scatter(df['study_hours'], df['final_marks'])
plt.title("Study Housr vs Final Marks")
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")
plt.grid()
plt.show()

# %%
plt.scatter(df['study_hours'], df['final_marks'], marker="s")
plt.title("Study Housr vs Final Marks")
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")
plt.grid()
plt.show()

# %%
plt.scatter(df['study_hours'], df['final_marks'], marker="s", color='green', lw=10)
plt.title("Study Housr vs Final Marks")
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")
plt.grid()
plt.show()

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
df.groupby('city').count()
# Out:
#            student_id  gender  program  semester  study_hours  attendance  \
# city
# Islamabad          20      20       20        20           20          20
# Karachi            36      36       36        36           36          36
# Lahore             29      29       29        29           29          29
# Multan             19      19       19        19           19          19
# Peshawar           58      58       58        58           58          58
# Quetta             22      22       22        22           22          22
#
#            prev_gpa  final_marks  scholarship
# city
# Islamabad        20           20           20
# Karachi          36           36           36
# Lahore           29           29           29
# Multan           19           19           19
# Peshawar         58           58           58
# Quetta           22           22           22

# %%
stu_count_by_city = df.groupby('city').count()['student_id']

# %%
stu_count_by_city
# Out:
# city
# Islamabad    20
# Karachi      36
# Lahore       29
# Multan       19
# Peshawar     58
# Quetta       22
# Name: student_id, dtype: int64

# %%
list(stu_count_by_city.index)
# Out:
# ['Islamabad', 'Karachi', 'Lahore', 'Multan', 'Peshawar', 'Quetta']

# %%
plt.bar(list(stu_count_by_city.index), stu_count_by_city)
# Out:
# <BarContainer object of 6 artists>

# %%
df.groupby("program").count()
# Out:
#          student_id  gender  city  semester  study_hours  attendance  \
# program
# BBA              45      45    45        45           45          45
# BSCS             74      74    74        74           74          74
# BSEE             25      25    25        25           25          25
# BSSE             40      40    40        40           40          40
#
#          prev_gpa  final_marks  scholarship
# program
# BBA            45           45           45
# BSCS           74           74           74
# BSEE           25           25           25
# BSSE           40           40           40

# %%
x = df['program'].unique()

# %%
x
# Out:
# array(['BBA', 'BSSE', 'BSCS', 'BSEE'], dtype=object)

# %%
y = df.groupby("program").count()['student_id']

# %%
y
# Out:
# program
# BBA     45
# BSCS    74
# BSEE    25
# BSSE    40
# Name: student_id, dtype: int64

# %%
plt.hist(df['study_hours'], edgecolor='black', bins=10)
plt.xticks(np.linspace(0.5, 30, 11).round(1))
plt.xlabel("study hours")
plt.ylabel("frequency")
plt.grid()
plt.show()

# %%
df['study_hours'].min()
# Out:
# 0.5

# %%
df['study_hours'].max()
# Out:
# 30.0

# %%
np.linspace(0.5, 30, 10)
# Out:
# array([ 0.5       ,  3.77777778,  7.05555556, 10.33333333, 13.61111111,
#        16.88888889, 20.16666667, 23.44444444, 26.72222222, 30.        ])

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
df['attendance'].plot(kind='hist', edgecolor='red', bins=10)
plt.xlabel("Attendance")
plt.xticks(l)
plt.show()

# %%
df['attendance'].min()
# Out:
# 54.2

# %%
l = range(50, 101, 5)

df['attendance'].plot(kind='hist', edgecolor='red', bins=10)
plt.xticks(l)
plt.xlabel("Attendance")
plt.show()

# %%
l = np.linspace(54.2, 100, 11)

df['attendance'].plot(kind='hist', edgecolor='red', bins=10)
plt.xticks(l)
plt.xlabel("Attendance")
plt.grid()
plt.show()

# %%
l = np.linspace(54.2, 100, 11)

df['attendance'].plot(kind='hist', edgecolor='red', bins=10)
plt.xticks(l)
plt.xlabel("Attendance")
plt.axvline(df['attendance'].mean(), color='r', linestyle='--', label='mean')
plt.axvline(df['attendance'].median(), c='#e0f007', ls=':', label='median')
plt.legend()
plt.grid()
plt.show()

# %%
df.attendance.mean()
# Out:
# 82.20271739130435

# %%
df.attendance.median()
# Out:
# 82.7

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
df['prev_gpa'].plot(kind='box', title="Student GPA Box plot")
plt.grid()
plt.show()

# %%
df['prev_gpa'].max()
# Out:
# 4.0

# %%
df['prev_gpa'].median()
# Out:
# 2.84

# %%
np.percentile(df['prev_gpa'], [25, 50, 75])
# Out:
# array([2.475, 2.84 , 3.24 ])

# %%
df['study_hours'].plot(kind='box', title="study hours box plot")
plt.axhline(df['study_hours'].median())
plt.show()

# %%
psc = df.groupby('program').count()['city']
psc
# Out:
# program
# BBA     45
# BSCS    74
# BSEE    25
# BSSE    40
# Name: city, dtype: int64

# %%
psc.index
# Out:
# Index(['BBA', 'BSCS', 'BSEE', 'BSSE'], dtype='object', name='program')

# %%
df['program'].unique()
# Out:
# array(['BBA', 'BSSE', 'BSCS', 'BSEE'], dtype=object)

# %%
sizes = df.groupby('program').count()['city']
labels = psc.index


plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
df.groupby('program').count()
# Out:
#          student_id  gender  city  semester  study_hours  attendance  \
# program
# BBA              45      45    45        45           45          45
# BSCS             74      74    74        74           74          74
# BSEE             25      25    25        25           25          25
# BSSE             40      40    40        40           40          40
#
#          prev_gpa  final_marks  scholarship
# program
# BBA            45           45           45
# BSCS           74           74           74
# BSEE           25           25           25
# BSSE           40           40           40

# %%
df.groupby('program').count()['city']
# Out:
# program
# BBA     45
# BSCS    74
# BSEE    25
# BSSE    40
# Name: city, dtype: int64
